# %%
import torch # type: ignore
import os

dtype = torch.complex128
device = torch.device("cpu")# torch.device("cuda" if torch.cuda.is_available() else "cpu")

pauli = torch.tensor([[[1,0],[0,1]],[[0,1],[1,0]],[[0,-1j],[1j,0]],[[1,0],[0,-1]]], device=device, dtype=dtype)
basis = torch.linalg.eig(pauli)[1][1:].mT # (3, 2, 2)


def shuffle(prepseq, shadow_state, rhoS):
    indices = torch.randperm(prepseq.shape[0])
    prepseq = prepseq[indices]
    shadow_state = shadow_state[indices]
    rhoS = rhoS[indices]
    return prepseq, shadow_state, rhoS

# %%
def torch_data(filename):
    data = {}
    for i in range(3):
        for j in range(3):
            m = torch.load(filename+f'_({i},{j}).pt')
            msk = torch.ones(m.shape[0], device=device, dtype=torch.bool)
            # post select on 2-qubit mitigation
            for anc, phy in [(0,6),
                             (1,7),
                             (2,8),
                             (3,9),
                             (12,13),
                             (20,21),
                             (28,29),
                             (36,37),
                             (19,18),
                             (27,26),
                             (35,34),
                             (43,42),
                             (51,46),
                             (52,47),
                             (53,48)
                             ]:
                msk = msk & (m[:,anc]==m[:,phy])
                #print((m[:,anc]==m[:,phy]).float().mean())
            # post select on 3-qubit mitigation
            for anc, phy in [(4,10),
                             (11,10),
                             (50,49),
                             (54,49)
                             ]:
                msk = msk & (m[:,anc]==m[:,phy])
                #print((m[:,anc]==m[:,phy]).float().mean())
            m = m[msk] # (batch, num_qubits)

            probe = torch.cat([m[:,10].view(-1,1), m[:,49].view(-1,1)], 1)
            prep = m[:,[5,6,7,8,9,
                        13,14,15,16,17,18,
                        21,22,23,24,25,26,
                        29,30,31,32,33,34,
                        37,38,39,40,41,42,
                        44,45,46,47,48]]
            data[(i,j)] = (prep, probe)
    prepseq, shadow_state, rhoS = [], [], []
    for k in data.keys():
        # construct post-measure state
        probseq = data[k][1].to(dtype=torch.int64).to(device=device) # (repetition, 2) last 2 outcomes
        obs_basis0 = basis[k[0]].unsqueeze(0).expand(probseq.shape[0], -1, -1) # (repetition, 2, 2)
        shadow_state0 = obs_basis0.gather(1, probseq[:,0].view(-1, 1, 1).expand(-1, -1, 2)).squeeze(1) # (repetition, 2)
        obs_basis1 = basis[k[1]].unsqueeze(0).expand(probseq.shape[0], -1, -1) # (repetition, 2, 2)
        shadow_state1 = obs_basis1.gather(1, probseq[:,1].view(-1, 1, 1).expand(-1, -1, 2)).squeeze(1) # (repetition, 2)
        shadow_state01 = torch.vmap(torch.kron)(shadow_state0, shadow_state1) # (batch, 4)
        # construct rhoS
        I = torch.eye(2, 2, device=device)[None,...].expand(shadow_state01.shape[0], -1, -1)
        rhoS0 = 3*torch.vmap(torch.outer)(shadow_state0, shadow_state0.conj()) - I
        rhoS1 = 3*torch.vmap(torch.outer)(shadow_state1, shadow_state1.conj()) - I
        rhoS01 = torch.vmap(torch.kron)(rhoS0, rhoS1)
        # collect result
        prepseq.append(data[k][0].to(dtype=torch.int64).to(device=device))
        shadow_state.append(shadow_state01)
        rhoS.append(rhoS01)
    prepseq = torch.cat(prepseq, 0).to(torch.int64)
    shadow_state = torch.cat(shadow_state, 0)
    rhoS = torch.cat(rhoS, 0)
    return prepseq, shadow_state, rhoS

# %%
def torch_data_single(filename):
    data = {}
    for i in range(3):
        m = torch.load(filename+f'_({i}).pt')
        msk = torch.ones(m.shape[0], device=device, dtype=torch.bool)
        # post select on 2-qubit mitigation
        for anc, phy in [(0,6),
                            (1,7),
                            (2,8),
                            (3,9),
                            (12,13),
                            (20,21),
                            (28,29),
                            (36,37),
                            (19,18),
                            (27,26),
                            (35,34),
                            (43,42),
                            (51,46),
                            (52,47),
                            (53,48)
                            ]:
            msk = msk & (m[:,anc]==m[:,phy])
            #print((m[:,anc]==m[:,phy]).float().mean())
        # post select on 3-qubit mitigation
        for anc, phy in [(4,10),
                            (11,10),
                            (50,49),
                            (54,49)
                            ]:
            msk = msk & (m[:,anc]==m[:,phy])
            #print((m[:,anc]==m[:,phy]).float().mean())
        m = m[msk] # (batch, num_qubits)

        probe = m[:,49].view(-1,1)
        prep = m[:,[5,6,7,8,9,10,
                    13,14,15,16,17,18,
                    21,22,23,24,25,26,
                    29,30,31,32,33,34,
                    37,38,39,40,41,42,
                    44,45,46,47,48]]
        data[(i,)] = (prep, probe)
    prepseq, shadow_state, rhoS = [], [], []
    for k in data.keys():
        # construct post-measure state
        probseq = data[k][1].to(dtype=torch.int64).to(device=device) # (repetition, 1) last 1 outcome
        obs_basis0 = basis[k[0]].unsqueeze(0).expand(probseq.shape[0], -1, -1) # (repetition, 2, 2)
        shadow_state0 = obs_basis0.gather(1, probseq[:,0].view(-1, 1, 1).expand(-1, -1, 2)).squeeze(1) # (repetition, 2)
        # construct rhoS
        I = torch.eye(2, 2, device=device)[None,...].expand(shadow_state0.shape[0], -1, -1)
        rhoS0 = 3*torch.vmap(torch.outer)(shadow_state0, shadow_state0.conj()) - I
        # collect result
        prepseq.append(data[k][0].to(dtype=torch.int64).to(device=device))
        shadow_state.append(shadow_state0)
        rhoS.append(rhoS0)
    prepseq = torch.cat(prepseq, 0).to(torch.int64)
    shadow_state = torch.cat(shadow_state, 0)
    rhoS = torch.cat(rhoS, 0)
    return prepseq, shadow_state, rhoS

# %%
folder_name = '6x6'
for theta_idx in range(11):
    for d in [6]:
        torch.manual_seed(0)
        all_prepseq = []
        all_shadow_state = []
        all_rhoS = []
        for loop in [0]:
            filename = f'data/{folder_name}_d={d}/theta{theta_idx}/loop{loop}/theta={theta_idx}'
            prepseq, shadow_state, rhoS = torch_data(filename, d)
            prepseq, shadow_state, rhoS = shuffle(prepseq, shadow_state, rhoS)
            all_prepseq.append(prepseq)
            all_shadow_state.append(shadow_state)
            all_rhoS.append(rhoS)
            print(f'distance={d}, loop={loop}, theta_idx={theta_idx}, portion to keep={((prepseq.shape[0]/9000000)):.4f}')
        all_prepseq = torch.cat(all_prepseq, 0)
        all_shadow_state = torch.cat(all_shadow_state, 0)
        all_rhoS = torch.cat(all_rhoS, 0)
        torch.save(all_prepseq, f'data/{folder_name}_d={d}/theta{theta_idx}/all_prepseq_theta={theta_idx}.pt')
        torch.save(all_shadow_state, f'data/{folder_name}_d={d}/theta{theta_idx}/all_shadow_state_theta={theta_idx}.pt')
        torch.save(all_rhoS, f'data/{folder_name}_d={d}/theta{theta_idx}/all_rhoS_theta={theta_idx}.pt')
        print(all_prepseq.shape, theta_idx)
        print(all_shadow_state.shape, theta_idx)
        print(all_rhoS.shape, theta_idx)
# Out:
# loop=0, theta_idx=4, portion to keep=0.7377
# torch.Size([1000000, 34]) 4
# torch.Size([1000000, 4]) 4
# torch.Size([1000000, 4, 4]) 4

# %%
for theta_idx in range(11):
    all_prepseq = []
    all_shadow_state = []
    all_rhoS = []
    torch.manual_seed(0)
    for loop in range(4):
        filename = f'data/Feb_1_cz_calibration_center/single_probe_{loop}/data_6x6/seq/theta={theta_idx}'
        prepseq, shadow_state, rhoS = torch_data_single(filename)
        prepseq, shadow_state, rhoS = shuffle(prepseq, shadow_state, rhoS)
        all_prepseq.append(prepseq)
        all_shadow_state.append(shadow_state)
        all_rhoS.append(rhoS)
        print(f'loop={loop}, theta_idx={theta_idx}, portion to keep={((prepseq.shape[0]/3000000)):.4f}')
    all_prepseq = torch.cat(all_prepseq, 0)
    all_shadow_state = torch.cat(all_shadow_state, 0)
    all_rhoS = torch.cat(all_rhoS, 0)
    torch.save(all_prepseq, f'data/Feb_1_cz_calibration_center/all_prepseq_theta={theta_idx}.pt')
    torch.save(all_shadow_state, f'data/Feb_1_cz_calibration_center/all_shadow_state_theta={theta_idx}.pt')
    torch.save(all_rhoS, f'data/Feb_1_cz_calibration_center/all_rhoS_theta={theta_idx}.pt')
    print(all_prepseq.shape, theta_idx)
    print(all_shadow_state.shape, theta_idx)
    print(all_rhoS.shape, theta_idx)
# Out:
# loop=0, theta_idx=0, portion to keep=0.7022
# loop=1, theta_idx=0, portion to keep=0.7193
# loop=2, theta_idx=0, portion to keep=0.7112
# loop=3, theta_idx=0, portion to keep=0.6837
# torch.Size([8449293, 35]) 0
# torch.Size([8449293, 2]) 0
# torch.Size([8449293, 2, 2]) 0
# loop=0, theta_idx=1, portion to keep=0.7050
# loop=1, theta_idx=1, portion to keep=0.7172
# loop=2, theta_idx=1, portion to keep=0.7107
# loop=3, theta_idx=1, portion to keep=0.6848
# torch.Size([8452981, 35]) 1
# torch.Size([8452981, 2]) 1
# torch.Size([8452981, 2, 2]) 1
# loop=0, theta_idx=2, portion to keep=0.6921
# loop=1, theta_idx=2, portion to keep=0.7094
# loop=2, theta_idx=2, portion to keep=0.7034
# loop=3, theta_idx=2, portion to keep=0.6968
# torch.Size([8404974, 35]) 2
# torch.Size([8404974, 2]) 2
# torch.Size([8404974, 2, 2]) 2
# loop=0, theta_idx=3, portion to keep=0.6985
# loop=1, theta_idx=3, portion to keep=0.7057
# loop=2, theta_idx=3, portion to keep=0.7115
# loop=3, theta_idx=3, portion to keep=0.6856
# torch.Size([8404184, 35]) 3
# torch.Size([8404184, 2]) 3
# torch.Size([8404184, 2, 2]) 3
# loop=0, theta_idx=4, portion to keep=0.6945
# loop=1, theta_idx=4, portion to keep=0.7067
# loop=2, theta_idx=4, portion to keep=0.7052
# loop=3, theta_idx=4, portion to keep=0.6900
# torch.Size([8389198, 35]) 4
# torch.Size([8389198, 2]) 4
# torch.Size([8389198, 2, 2]) 4
# loop=0, theta_idx=5, portion to keep=0.6917
# loop=1, theta_idx=5, portion to keep=0.7045
# loop=2, theta_idx=5, portion to keep=0.6973
# loop=3, theta_idx=5, portion to keep=0.6908
# torch.Size([8352639, 35]) 5
# torch.Size([8352639, 2]) 5
# torch.Size([8352639, 2, 2]) 5
# loop=0, theta_idx=6, portion to keep=0.6901
# loop=1, theta_idx=6, portion to keep=0.7173
# loop=2, theta_idx=6, portion to keep=0.6956
# loop=3, theta_idx=6, portion to keep=0.6961
# torch.Size([8397358, 35]) 6
# torch.Size([8397358, 2]) 6
# torch.Size([8397358, 2, 2]) 6
# loop=0, theta_idx=7, portion to keep=0.7000
# loop=1, theta_idx=7, portion to keep=0.6994
# loop=2, theta_idx=7, portion to keep=0.7040
# loop=3, theta_idx=7, portion to keep=0.6795
# torch.Size([8348525, 35]) 7
# torch.Size([8348525, 2]) 7
# torch.Size([8348525, 2, 2]) 7
# loop=0, theta_idx=8, portion to keep=0.7213
# loop=1, theta_idx=8, portion to keep=0.6941
# loop=2, theta_idx=8, portion to keep=0.6881
# loop=3, theta_idx=8, portion to keep=0.7021
# torch.Size([8416951, 35]) 8
# torch.Size([8416951, 2]) 8
# torch.Size([8416951, 2, 2]) 8
# loop=0, theta_idx=9, portion to keep=0.7254
# loop=1, theta_idx=9, portion to keep=0.7048
# loop=2, theta_idx=9, portion to keep=0.6937
# loop=3, theta_idx=9, portion to keep=0.7076
# torch.Size([8494498, 35]) 9
# torch.Size([8494498, 2]) 9
# torch.Size([8494498, 2, 2]) 9
# loop=0, theta_idx=10, portion to keep=0.7209
# loop=1, theta_idx=10, portion to keep=0.7095
# loop=2, theta_idx=10, portion to keep=0.6884
# loop=3, theta_idx=10, portion to keep=0.7035
# torch.Size([8466734, 35]) 10
# torch.Size([8466734, 2]) 10
# torch.Size([8466734, 2, 2]) 10
