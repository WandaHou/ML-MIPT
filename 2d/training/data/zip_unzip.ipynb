# %%
# !zip -r train_with_exp_anc.zip train_with_exp_anc
# Out:
#   adding: train_with_exp_anc/ (stored 0%)
#   adding: train_with_exp_anc/shallow.py (deflated 84%)
#   adding: train_with_exp_anc/train_on_data.ipynb (deflated 70%)
#   adding: train_with_exp_anc/load_data.ipynb (deflated 83%)
#   adding: train_with_exp_anc/__pycache__/ (stored 0%)
#   adding: train_with_exp_anc/__pycache__/Llama2.cpython-310.pyc (deflated 64%)
#   adding: train_with_exp_anc/__pycache__/simulator.cpython-310.pyc (deflated 45%)
#   adding: train_with_exp_anc/__pycache__/utils.cpython-310.pyc (deflated 40%)
#   adding: train_with_exp_anc/utils.py (deflated 65%)
#   adding: train_with_exp_anc/zip_unzip.ipynb (deflated 84%)
#   adding: train_with_exp_anc/data/ (stored 0%)
#   adding: train_with_exp_anc/.DS_Store (deflated 94%)
#   adding: train_with_exp_anc/data_evaluation.ipynb (deflated 77%)
#   adding: train_with_exp_anc/Llama2.py (deflated 80%)
#   adding: train_with_exp_anc/simulator.py (deflated 75%)
#   adding: train_with_exp_anc/save/ (stored 0%)
# ...

# %%
! unzip theta4.zip
# Out:
# Archive:  theta4.zip
#    creating: theta4/
#   inflating: theta4/.DS_Store
#   inflating: __MACOSX/theta4/._.DS_Store
#    creating: theta4/loop0/
#    creating: theta4/loop1/
#    creating: theta4/loop10/
#    creating: theta4/loop11/
#    creating: theta4/loop12/
#    creating: theta4/loop13/
#    creating: theta4/loop14/
#    creating: theta4/loop15/
#    creating: theta4/loop16/
#    creating: theta4/loop17/
#    creating: theta4/loop2/
#    creating: theta4/loop3/
#    creating: theta4/loop4/
#    creating: theta4/loop5/
#    creating: theta4/loop6/
#    creating: theta4/loop7/
#    creating: theta4/loop8/
#    creating: theta4/loop9/
#   inflating: theta4/loop0/theta=4_(0,0).pt
#   inflating: __MACOSX/theta4/loop0/._theta=4_(0,0).pt
#   inflating: theta4/loop0/theta=4_(0,1).pt
#   inflating: __MACOSX/theta4/loop0/._theta=4_(0,1).pt
#   inflating: theta4/loop0/theta=4_(0,2).pt
#   inflating: __MACOSX/theta4/loop0/._theta=4_(0,2).pt
#   inflating: theta4/loop0/theta=4_(1,0).pt
# ...

# %%
pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 20.6 MB/s eta 0:00:0000:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.5/450.5 KB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 KB 66.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 27.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 55.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
